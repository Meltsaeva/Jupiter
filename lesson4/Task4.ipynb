# %% [markdown]
# ### №4.1. "laptops-prices"
#
# - Скачать данные по ссылке https://drive.google.com/file/d/1MpAdHAl727fO3oW32NO4FpSRhUBUfjfS
#
# - Считать данные с помощью pandas
#
# - Вывести на экран первые 5 строк
#
# Для всех пунктов:
#
# - Постройте график
#
# - Назовите график
#
# - Сделайте именование оси x и оси y
#
# - Сделайте выводы

# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import numpy as np

# %%
df = pd.read_csv('GB.SEM.laptops-prices.csv', encoding='cp1251')

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                         Cpu   Ram  \
# 0   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz   8GB
# 2      HP       250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  MacBook Pro  Ultrabook    15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 3.1GHz   8GB
#
#                             Gpu  OpSys  Weight  Price_euros Cpu_Company  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69       Intel
# 1        Intel HD Graphics 6000  macOS    1.34       898.94       Intel
# 2         Intel HD Graphics 620  No OS    1.86       575.00       Intel
# 3            AMD Radeon Pro 455  macOS    1.83      2537.45       Intel
# 4  Intel Iris Plus Graphics 650  macOS    1.37      1803.60       Intel
#
#    Memory_Amount   Memory_Type
# 0            128           SSD
# ...

# %% [markdown]
# #### 1.1 Изучите количество памяти с помощью matplotlib

# %%
plt.figure()
plt.hist(df['Memory_Amount'], bins=50)
plt.xlabel('Memory size')
plt.ylabel('A number of computers')
plt.title('Memory allocation')
#plt.grid()
# Out:
# Text(0.5, 1.0, 'Memory allocation')

# %% [markdown]
# #### 1.2 Изучите стоимость ноутбуков с помощью matplotlib

# %%
plt.figure()
plt.hist(df['Price_euros'], bins=50)
plt.xlabel('Price')
plt.ylabel('A number of computers')
plt.title('The cost of computers')
# Out:
# Text(0.5, 1.0, 'The cost of computers')

# %%
plt.figure()
plt.boxplot(df['Price_euros'])
plt.ylabel('A number of computers')
plt.title('The cost of computers')
# Out:
# Text(0.5, 1.0, 'The cost of computers')

# %% [markdown]
# #### 1.3 Изучите вес ноутбуков с помощью matplotlib

# %%
plt.figure()
plt.hist(df['Weight'], bins=50)
plt.xlabel('kg')
plt.ylabel('A number of computers')
plt.title('Weight of computers')
# Out:
# Text(0.5, 1.0, 'Weight of computers')

# %%
sns.histplot(data=df, x='Weight', hue='TypeName')
# Out:
# <Axes: xlabel='Weight', ylabel='Count'>

# %% [markdown]
# ### №4.2. "laptops-prices"
#
# #### 2.1 Изучите распределение типов носителя

# %%
df.head()
# Out:
#   Company      Product   TypeName  Inches                         Cpu   Ram  \
# 0   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 2.3GHz   8GB
# 1   Apple  Macbook Air  Ultrabook    13.3        Intel Core i5 1.8GHz   8GB
# 2      HP       250 G6   Notebook    15.6  Intel Core i5 7200U 2.5GHz   8GB
# 3   Apple  MacBook Pro  Ultrabook    15.4        Intel Core i7 2.7GHz  16GB
# 4   Apple  MacBook Pro  Ultrabook    13.3        Intel Core i5 3.1GHz   8GB
#
#                             Gpu  OpSys  Weight  Price_euros Cpu_Company  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37      1339.69       Intel
# 1        Intel HD Graphics 6000  macOS    1.34       898.94       Intel
# 2         Intel HD Graphics 620  No OS    1.86       575.00       Intel
# 3            AMD Radeon Pro 455  macOS    1.83      2537.45       Intel
# 4  Intel Iris Plus Graphics 650  macOS    1.37      1803.60       Intel
#
#    Memory_Amount   Memory_Type
# 0            128           SSD
# ...

# %%
df['Memory_Type'].describe()
# Out:
# count     1303
# unique       4
# top        SSD
# freq       641
# Name: Memory_Type, dtype: object

# %%
df['Memory_Type'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1303 entries, 0 to 1302
# Series name: Memory_Type
# Non-Null Count  Dtype
# --------------  -----
# 1303 non-null   object
# dtypes: object(1)
# memory usage: 10.3+ KB

# %%
data_pie = df['Memory_Type'].value_counts()

# %%
data_pie
# Out:
# Memory_Type
# SSD             641
# HDD             576
# FlashStorage     74
# Hybrid           12
# Name: count, dtype: int64

# %%
plt.figure()
plt.pie(data_pie.values, labels=data_pie.index, autopct='%.1f%%')
plt.show()

# %% [markdown]
# #### 2.2 Изучите распределение компаний производителей

# %%
data_pie = df['Company'].value_counts()
data_pie
# Out:
# Company
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
plt.figure()
plt.pie(data_pie.values, labels=data_pie.index, autopct='%.1f%%')
plt.show()

# %%
plt.figure()
plt.bar(data_pie.index, data_pie.values)
plt.xticks(rotation=50);

# %% [markdown]
# #### 2.3 Изучите распределение операционной системы

# %%
data_pie = df['OpSys'].value_counts()
data_pie
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
plt.figure()
plt.bar(data_pie.index, data_pie.values)
plt.xticks(rotation=50);

# %%
data_pie = df[df['OpSys'] != 'Windows 10']['OpSys'].value_counts()
data_pie
# Out:
# OpSys
# No OS           66
# Linux           62
# Windows 7       45
# Chrome OS       27
# macOS           13
# Mac OS X         8
# Windows 10 S     8
# Android          2
# Name: count, dtype: int64

# %% [markdown]
# #### 2.4 Изучите распределение компаний производителей CPU
#
# - Постройте график
#
# - Сделайте выводы

# %%
data_pie = df['Cpu_Company'].value_counts()
data_pie
# Out:
# Cpu_Company
# Intel      1240
# AMD          62
# Samsung       1
# Name: count, dtype: int64

# %%
plt.figure()
plt.pie(data_pie.values, labels=data_pie.index, autopct='%.1f%%')
plt.show()

# %% [markdown]
# ### №4.3. Изучите взаимосвязь компаний производителей ноутбуков и компаний производителей процессоров, используя сложенную или многорядовую столбчатую диаграмму
#
# Процессоры от Samsung не изучайте
#
# 3.1 Постройте график в абсолютных величинах
#
# 3.2 Постройте график в относительных величинах

# %%
data = (pd.crosstab(df['Company'], df['Cpu_Company'])).drop(columns='Samsung').reset_index()
data
# Out:
# Cpu_Company    Company  AMD  Intel
# 0                 Acer   10     93
# 1                Apple    0     21
# 2                 Asus   11    147
# 3                Chuwi    0      3
# 4                 Dell    0    297
# 5              Fujitsu    0      3
# 6               Google    0      3
# 7                   HP   25    249
# 8               Huawei    0      2
# 9                   LG    0      3
# 10              Lenovo   16    281
# 11                 MSI    0     54
# 12            Mediacom    0      7
# 13           Microsoft    0      6
# 14               Razer    0      7
# 15             Samsung    0      8
# 16             Toshiba    0     48
# 17                Vero    0      4
# 18              Xiaomi    0      4

# %%
plt.figure(figsize=(8,6))
n_ticks =np.arange(len(data['Intel']))
offset = 0.2
w = 0.4
plt.bar(n_ticks - offset, data['Intel'], width=w)
plt.bar(n_ticks - offset, data['AMD'], width=w)
plt.title('the relationship between laptop manufacturing companies and processor manufacturing companies')
plt.xlabel("")
plt.ylabel('')
plt.xticks(n_ticks, data['Company'], rotation=30);

# %%
# Строим столбчатую многорядную диаграмму

plt.figure(figsize=(10, 6))

# определяем кол-во делений
n_ticks = np.arange(len(data['AMD']))

# определяем сдвиг
offset = 0.2

# определяем ширину столбцов
w = 0.4

# добавляем сдвиг к кол-ву делений
plt.bar(n_ticks - offset, data['AMD'], width=w)
plt.bar(n_ticks + offset, data['Intel'], width=w)

plt.title('Компании производители и процессоры')
plt.xlabel('Компании')
plt.ylabel('Кол-во')
plt.legend(['AMD', 'Intel'])
plt.xticks(n_ticks, data['Company'], rotation = 30);  # добавляем метки делений

# %%
data_3 = df[['Cpu_Company', 'Company']].value_counts().unstack('Cpu_Company').fillna(0).drop(columns=['Samsung']).reset_index()
data_3
# Out:
# Cpu_Company    Company   AMD  Intel
# 0                 Acer  10.0   93.0
# 1                Apple   0.0   21.0
# 2                 Asus  11.0  147.0
# 3                Chuwi   0.0    3.0
# 4                 Dell   0.0  297.0
# 5              Fujitsu   0.0    3.0
# 6               Google   0.0    3.0
# 7                   HP  25.0  249.0
# 8               Huawei   0.0    2.0
# 9                   LG   0.0    3.0
# 10              Lenovo  16.0  281.0
# 11                 MSI   0.0   54.0
# 12            Mediacom   0.0    7.0
# 13           Microsoft   0.0    6.0
# 14               Razer   0.0    7.0
# 15             Samsung   0.0    8.0
# 16             Toshiba   0.0   48.0
# 17                Vero   0.0    4.0
# 18              Xiaomi   0.0    4.0

# %%
data_3 = pd.crosstab(index = df['Company'],
        columns=df['Cpu_Company'],
        normalize = 'index').drop(columns=['Samsung'], index = 'Samsung').reset_index()
data_3
# Out:
# Cpu_Company    Company       AMD     Intel
# 0                 Acer  0.097087  0.902913
# 1                Apple  0.000000  1.000000
# 2                 Asus  0.069620  0.930380
# 3                Chuwi  0.000000  1.000000
# 4                 Dell  0.000000  1.000000
# 5              Fujitsu  0.000000  1.000000
# 6               Google  0.000000  1.000000
# 7                   HP  0.091241  0.908759
# 8               Huawei  0.000000  1.000000
# 9                   LG  0.000000  1.000000
# 10              Lenovo  0.053872  0.946128
# 11                 MSI  0.000000  1.000000
# 12            Mediacom  0.000000  1.000000
# 13           Microsoft  0.000000  1.000000
# 14               Razer  0.000000  1.000000
# 15             Toshiba  0.000000  1.000000
# 16                Vero  0.000000  1.000000
# 17              Xiaomi  0.000000  1.000000

# %%
plt.figure(figsize=(10, 6))
n_ticks = np.arange(len(data_3['AMD']))
w = 0.8
plt.bar(n_ticks, data_3['AMD'], width=w)
plt.bar(n_ticks, data_3['Intel'], width=w, bottom=data_3['AMD'])
plt.title('Компании производители и процессоры')
plt.xlabel('Компании')
plt.ylabel('Кол-во')
plt.legend(['AMD', 'Intel'])
plt.xticks(n_ticks, data_3['Company'], rotation = 30);  # добавляем метки делений

# %% [markdown]
# ### №4.4. Изучите зависимости
#
# #### 4.1 Изучите взаимосвязь стоимости ноутбука и компании производителя процессора

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['Price_euros'], y=df['Cpu_Company'])
plt.title('The relationship between the cost of a laptop and a company')
plt.xlabel('Price_euros')
plt.ylabel('Cpu_Company');

# %% [markdown]
# #### 4.2 Изучите взаимосвязь стоимости ноутбука и типа носителя памяти

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['Price_euros'], y=df['Memory_Type'])
plt.title('the relationship between the cost of a laptop and the type of storage medium')
plt.xlabel('Price_euros')
plt.ylabel('Memory Type');

# %% [markdown]
# #### 4.3 Изучите взаимосвязь стоимости ноутбука и кол-ва оперативной памяти

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['Price_euros'], y=df['Ram'])
plt.title('the relationship between the cost of a laptop and the amount of RAM')
plt.xlabel('Price_euros')
plt.ylabel('Ram');

# %% [markdown]
# #### 4.4 Изучите взаимосвязь стоимости ноутбука и компании производителя
#
# -Постройте график
#
# -Назовите график
#
# -Сделайте именование оси x и оси y
#
# -Сделайте выводы

# %%
plt.figure(figsize=(6, 4))
sns.boxplot(x=df['Price_euros'], y=df['Company'])
plt.title('the relationship between the cost of a laptop and a company')
plt.xlabel('Price_euros')
plt.ylabel('Company');

# %% [markdown]
# ### №4.5 Постройте матрицу корреляций для таблицы

# %%
matrix = df.corr(numeric_only=True)
matrix = np.round(matrix,1)
matrix
# Out:
#                Inches  Weight  Price_euros  Memory_Amount
# Inches            1.0     0.8          0.1            0.3
# Weight            0.8     1.0          0.2            0.2
# Price_euros       0.1     0.2          1.0           -0.1
# Memory_Amount     0.3     0.2         -0.1            1.0

# %%
plt.figure(figsize=(10, 8))
sns.set(font_scale=1.4)
sns.heatmap(matrix, annot=True, linewidths=.5, cmap='coolwarm')
plt.title('Correlation matrix');
